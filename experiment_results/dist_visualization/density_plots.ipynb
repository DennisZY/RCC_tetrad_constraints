# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_50 = pd.read_csv('spirtes_random_b0.1_d0.1_samples50_n0.csv')
df_1000 = pd.read_csv('spirtes_random_b0.1_d0.1_samples1000_n0.csv')
df_50_not_scaled = pd.read_csv('50_not_scaled.csv')
df_1000_not_scaled = pd.read_csv('1000_not_scaled.csv')

# %%
df.columns
# Out:
# Index(['X1', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X2',
#        'X3', 'X4', 'X5', 'X6', 'X7', 'X8'],
#       dtype='object')

# %%
plt.style.use('fivethirtyeight')
sns.kdeplot(data = df_1000[['X1','X2','X3','X4']], linewidth =0.9)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.style.use('fivethirtyeight')
sns.kdeplot(data = df_1000[['X3','X4','X5','X6']], linewidth =0.9)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ##
