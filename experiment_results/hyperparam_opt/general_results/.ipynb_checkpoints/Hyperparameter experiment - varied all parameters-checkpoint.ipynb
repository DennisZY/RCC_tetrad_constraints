# %%
import pandas as pd
import numpy as np
import tabulate
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read in data

# %%
results = pd.read_csv('experiment_general_results.csv')
results_complete = pd.read_csv('experiment_general_results_complete_graph.csv')
wish_results1 = pd.read_csv('wishart_experiments/wishart_experiment_adjusted_wish_results2.csv')
wish_results2 = pd.read_csv('wishart_experiments/wishart_compare_with_general_results.csv')
wish_results3 = pd.read_csv('wishart_experiments/wishart_compare_with_general2_results.csv')
#wish_results = wish_results2[wish_results2['nsamples'] == 500]
wish_results = wish_results3

# %% [markdown]
# Import KME results in correct format and extract true positive and false positive rates.

# %%
results = results[(results['n_samples'] == 200) & (results['n_distributions'] == 200)]
results_mean = results.groupby(['b','d','KME','E','K','n_samples','n_distributions']).mean()
results_mean.insert(1, 'acc_std', results.groupby(['b','d','KME','E','K','n_samples','n_distributions'])[['score']].std())

true_pos = results_mean['truepos'] / (results_mean['truepos'] + results_mean['falseneg'])
false_pos = results_mean['falsepos'] / (results_mean['falsepos'] + results_mean['trueneg'])

#print(results_mean.reset_index().to_markdown())

# %% [markdown]
# Import KME results for the complete Spirtes graph in the correct format and extract true positive and false positive rates.

# %%
results_mean_comp = results_complete
#results_mean_comp = results_complete.groupby(['b','d','KME','E','K','n_samples','n_distributions']).mean()
#results_mean_comp.insert(1, 'acc_std', results_complete.groupby(['b','d','KME','E','K','n_samples','n_distributions'])[['score']].std())

true_pos_comp = results_mean_comp['truepos'] / (results_mean_comp['truepos'] + results_mean_comp['falseneg'])
false_pos_comp = results_mean_comp['falsepos'] / (results_mean_comp['falsepos'] + results_mean_comp['trueneg'])

#print(results_mean_comp.reset_index().to_markdown())

# %% [markdown]
# Import Wishart results in correect format and extract true positive and false positive rates.

# %%
wish_results_lin = wish_results[wish_results['linear'] == True] 
wish_results_nonlin = wish_results[wish_results['linear'] == False] 

wish_results_lin_mean = wish_results_lin
wish_results_nonlin_mean = wish_results_nonlin
#wish_results_lin_mean = wish_results_lin.groupby(['b','d','nsamples']).mean()
#wish_results_lin_mean.insert(2, 'acc_std', wish_results_lin.groupby(['b','d','nsamples'])[['accuracy']].std())
#wish_results_nonlin_mean = wish_results_nonlin.groupby(['b','d','nsamples']).mean()
#wish_results_nonlin_mean.insert(2, 'acc_std', wish_results_nonlin.groupby(['b','d','nsamples'])[['accuracy']].std())

true_pos_wish_lin = wish_results_lin_mean['truepos'] / (wish_results_lin_mean['truepos'] + wish_results_lin_mean['falseneg'])
false_pos_wish_lin = wish_results_lin_mean['falsepos'] / (wish_results_lin_mean['falsepos'] + wish_results_lin_mean['trueneg'])
true_pos_wish_nonlin = wish_results_nonlin_mean['truepos'] / (wish_results_nonlin_mean['truepos'] + wish_results_nonlin_mean['falseneg'])
false_pos_wish_nonlin = wish_results_nonlin_mean['falsepos'] / (wish_results_nonlin_mean['falsepos'] + wish_results_nonlin_mean['trueneg'])

# %% [markdown]
# ### Graph displaying the True Positive Rate and False Positive Rate of the KME and Wishart test with different hyperparameters

# %%
plt.plot(false_pos,true_pos, 'r.',label='KME')    
plt.plot(false_pos_wish_nonlin, true_pos_wish_nonlin, 'b.',label='nonlin Wishart')
plt.plot(false_pos_wish_lin,true_pos_wish_lin,'g.', label='lin Wishart')
plt.plot([0,1],'k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %% [markdown]
# Plot comparing the KME on the different graphs

# %%
plt.plot(false_pos,true_pos, 'r.',label='KME small graph')    
plt.plot(false_pos_comp, true_pos_comp, 'b.',label='KME large graph')
plt.plot([0,1],'k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
plt.plot(false_pos_wish_nonlin, true_pos_wish_nonlin, 'r.',label='nonlin Wishart')
plt.plot(false_pos_wish_lin,true_pos_wish_lin,'g.', label='lin Wishart')
plt.plot(false_pos_comp, true_pos_comp, 'b.',label='KME large graph')
plt.plot([0,1],'k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
true_pos.reset_index().corr()
# Out:
#                             b             d  KME             E             K  \
# b                1.000000e+00  2.258755e-17  NaN -1.495326e-17  0.000000e+00
# d                2.258755e-17  1.000000e+00  NaN -1.495326e-17  0.000000e+00
# KME                       NaN           NaN  NaN           NaN           NaN
# E               -1.495326e-17 -1.495326e-17  NaN  1.000000e+00  2.969779e-17
# K                0.000000e+00  0.000000e+00  NaN  2.969779e-17  1.000000e+00
# n_samples                 NaN           NaN  NaN           NaN           NaN
# n_distributions           NaN           NaN  NaN           NaN           NaN
# 0                5.558738e-01  3.426269e-02  NaN -2.063718e-02 -1.148605e-01
#
#                  n_samples  n_distributions         0
# b                      NaN              NaN  0.555874
# d                      NaN              NaN  0.034263
# KME                    NaN              NaN       NaN
# E                      NaN              NaN -0.020637
# K                      NaN              NaN -0.114861
# n_samples              NaN              NaN       NaN
# n_distributions        NaN              NaN       NaN
# 0                      NaN              NaN  1.000000

# %%
false_pos.reset_index().corr()
# Out:
#                             b             d  KME             E             K  \
# b                1.000000e+00  2.258755e-17  NaN -1.495326e-17  0.000000e+00
# d                2.258755e-17  1.000000e+00  NaN -1.495326e-17  0.000000e+00
# KME                       NaN           NaN  NaN           NaN           NaN
# E               -1.495326e-17 -1.495326e-17  NaN  1.000000e+00  2.969779e-17
# K                0.000000e+00  0.000000e+00  NaN  2.969779e-17  1.000000e+00
# n_samples                 NaN           NaN  NaN           NaN           NaN
# n_distributions           NaN           NaN  NaN           NaN           NaN
# 0                4.811256e-01 -1.136947e-01  NaN  6.610410e-02  5.391908e-01
#
#                  n_samples  n_distributions         0
# b                      NaN              NaN  0.481126
# d                      NaN              NaN -0.113695
# KME                    NaN              NaN       NaN
# E                      NaN              NaN  0.066104
# K                      NaN              NaN  0.539191
# n_samples              NaN              NaN       NaN
# n_distributions        NaN              NaN       NaN
# 0                      NaN              NaN  1.000000

# %%
results_mean.reset_index().corr()['score']
# Out:
# b                  0.033270
# d                  0.138738
# KME                     NaN
# E                 -0.081299
# K                 -0.615798
# n_samples               NaN
# n_distributions         NaN
# score              1.000000
# acc_std            0.172232
# trueneg            0.590290
# falseneg          -0.493866
# truepos            0.493866
# falsepos          -0.590290
# Name: score, dtype: float64
